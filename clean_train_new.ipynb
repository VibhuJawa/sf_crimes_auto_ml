# %%
import pandas as pd

# %%
df_new = pd.read_csv("data/test_new.csv",header=None)

# %%
df_old = pd.read_csv("old_test.csv")

# %%
list(df_old.columns.values)
# Out:
# ['Id', 'Dates', 'DayOfWeek', 'PdDistrict', 'Address', 'X', 'Y']

# %%
df_new.columns = ['Dates', 'Label','DayOfWeek', 'PdDistrict', 'Address', 'X', 'Y']

# %%
df_new['Label'].to_csv("data/test_labels.csv")

# %%
df_new[df_new.columns.difference(['Label'])].to_csv('data/test_updated.csv',index=None)

# %%
df_test = pd.read_csv('data/test_updated.csv')

# %%
df_test
# Out:
#                             Address                Dates  DayOfWeek  \
# 0          1300 Block of VANNESS AV  2010-02-26 12:52:00     Friday
# 1             200 Block of GATES ST  2004-06-25 18:45:00     Friday
# 2           1200 Block of IRVING ST  2010-07-29 13:11:00   Thursday
# 3         2400 Block of FILLMORE ST  2012-04-22 14:50:00     Sunday
# 4              1900 Block of 9TH AV  2005-05-22 19:11:00     Sunday
# 5         200 Block of SANCARLOS ST  2005-08-12 12:00:00     Friday
# 6       MCALLISTER ST / FILLMORE ST  2014-08-23 18:00:00   Saturday
# 7          LAKE MERCED BL / FONT BL  2009-10-30 05:22:00     Friday
# 8            800 Block of BRYANT ST  2006-07-10 16:17:00     Monday
# 9             1500 Block of 43RD AV  2009-01-09 13:50:00     Friday
# 10         300 Block of GUERRERO ST  2008-10-02 12:00:00   Thursday
# 11          1700 Block of LARKIN ST  2004-04-03 09:00:00   Saturday
# 12           20TH ST / HAMPSHIRE ST  2013-09-06 18:24:00     Friday
# ...

# %%
df_train = pd.read_csv('data/train_new.csv',header=None)

# %%
df_train.columns = ['Dates', 'Category','DayOfWeek', 'PdDistrict', 'Address', 'X', 'Y']

# %%
df_train.to_csv('data/train_updated.csv',index=False)

# %%
df_train = pd.read_csv("data/train_updated.csv")

# %%
df_train
# Out:
#                       Dates            Category  DayOfWeek  PdDistrict  \
# 0       2005-12-04 02:22:00           LOITERING     Sunday  TENDERLOIN
# 1       2007-09-23 06:15:00           LOITERING     Sunday     MISSION
# 2       2008-06-26 10:00:00             RUNAWAY   Thursday     MISSION
# 3       2005-01-27 20:59:00             RUNAWAY   Thursday        PARK
# 4       2012-05-16 20:48:00             RUNAWAY  Wednesday     MISSION
# 5       2007-09-09 17:00:00           LOITERING     Sunday    SOUTHERN
# 6       2008-11-15 11:00:00           LOITERING   Saturday    SOUTHERN
# 7       2012-09-22 14:30:00             RUNAWAY   Saturday     TARAVAL
# 8       2004-05-12 08:45:00             SUICIDE  Wednesday    RICHMOND
# 9       2010-10-04 07:30:00             RUNAWAY     Monday     MISSION
# 10      2007-07-14 01:45:00   RECOVERED VEHICLE   Saturday     MISSION
# 11      2003-07-08 11:30:00             RUNAWAY    Tuesday     TARAVAL
# ...
